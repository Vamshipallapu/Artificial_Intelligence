# %% [markdown]
# Optimization comes in to picture where we are generating some revenue or saving some revenue either by Maximizing sales or minimizing resources.

# %% [markdown]
# let me tell you with an example:
#
# case 1: suppose we have a figure , and we need to acheive that sales figure eg: 250 cr
#
# Now in this case to acheive that figure we need to take consideration of minnimum possible resources, so here its ike Optimizing resources. So using as minimal resources as possible we need to acheive that figure.
#
# Case 2: Suppose we have resources of figure eg : 5CR , Now Optimizing is like investing these resources wisely into different things here we are optimizing sales, that means maximing sales here.
#
# Note: Resources in the sense those could be any campaigns like that.

# %% [markdown]
# We use Regression models in MMM where

# %% [markdown]
# ![image.png](data:image/png;base64,...)
