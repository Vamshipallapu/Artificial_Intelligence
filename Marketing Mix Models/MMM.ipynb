# %% [markdown]
# **Linear Regression Models:**
#
# Example: Ordinary Least Squares (OLS) regression
#
# Use case: Analyzing the relationship between advertising spending and sales revenue.
#
# **Linear Regression Models:**
#
# Ordinary Least Squares (OLS) regression
#
# Poisson regression
#
# Ridge regression
#
# Lasso regression
#
# Elastic Net regression
#
# =====================================
#
# **Time Series Models:**
#
# Example: Autoregressive Integrated Moving Average (ARIMA)
#
# Use case: Forecasting future sales based on historical sales data.
#
# **Time Series Models:**
# Autoregressive Integrated Moving Average (ARIMA)
#
# Seasonal Decomposition of Time Series (STL)
#
# Exponential Smoothing Methods (e.g., Holt-Winters)
#
# Vector Autoregression (VAR)
#
# Seasonal Autoregressive Integrated Moving Average (SARIMA)
#
# =========================================
#
# **Econometric Models:**
#
# Example: Vector Autoregression (VAR)
#
# Use case: Incorporating economic indicators (e.g., GDP, inflation) into marketing analysis to predict sales.
#
# **Econometric Models:**
#
# Vector Error Correction Model (VECM)
#
# Dynamic Linear Models (DLM)
#
# Bayesian Vector Autoregression (BVAR)
#
# Simultaneous Equation Models (SEM)
#
# Structural Equation Models (SEM)
#
# ==============================================
#
# **Attribution Models:**
#
# Example: First-touch attribution
#
# Use case: Assigning credit to the first marketing touchpoint a customer interacts with before making a purchase.
#
# **Attribution Models:**
#
# First-touch attribution
#
# Last-touch attribution
#
# Linear attribution
#
# Time-decay attribution
#
# Position-based attribution (e.g., U-shaped, W-shaped)
#
#
# ==============================================
#
# **Multivariate Regression Models:**
#
# Example: Multiple Linear Regression
#
# Use case: Assessing the combined impact of advertising, promotions, and pricing on product sales.
#
# **Multivariate Regression Models:**
#
# Multiple Linear Regression
#
# Polynomial Regression
#
# Generalized Linear Models (GLMs)
#
# Multivariate Adaptive Regression Splines (MARS)
#
# Partial Least Squares Regression (PLSR)
#
# =============================================
#
# **Marketing Mix Models (MMM):**
#
# Example: Marketing Mix Modeling using time series analysis and regression
#
# Use case: Analyzing the effects of various marketing activities on sales over time.
#
#
# **Marketing Mix Models (MMM):**
#
# Time series regression models with lagged variables
#
# Distributed lag models
#
# Cross-sectional regression models
#
# Vector Autoregression with exogenous variables (VARX)
#
# Bayesian structural time series models (BSTS)
#
# =============================================
#
# **Bayesian Models:**
#
# Example: Bayesian Structural Time Series (BSTS)
#
# Use case: Estimating the uncertainty associated with marketing ROI predictions.
#
# **Bayesian Models:**
#
# Bayesian Hierarchical Models
#
# Bayesian Vector Autoregression (BVAR)
#
# Bayesian Structural Time Series (BSTS)
#
# Bayesian Generalized Linear Models (BGLM)
#
# Bayesian Additive Regression Trees (BART)
#
# ============================================
#
# **Machine Learning Models:**
#
# Example: Random Forest Regression
#
# Use case: Predicting sales using machine learning algorithms trained on historical marketing and sales data.
#
# **Machine Learning Models:**
#
# Random Forest Regression
#
# Gradient Boosting Machines (GBM)
#
# Support Vector Regression (SVR)
#
# Neural Networks (e.g., Feedforward, LSTM)
#
# K-Nearest Neighbors Regression (KNN)
