# %% [markdown]
# One of the Data requests we do for like
#
# Sales/Transaction Data
#
# Promotion/Discount Data - Price Sensitive Data.

# %% [markdown]
# Data sources for these kinds of data will be like ERP,CRM,Data Warehouse etc.,

# %% [markdown]
# On the other hand
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Through these Marketing agencies, API's, Marketing Dept, Internal Reports we usually get Data like
#
# Data Categories:
#
# KPI's : Key Performance Indicators (ROI(Return on Investment),Customer Aquisition cost, MQL(Marketing Qualified Lead and SQL(Sales Qualified Lead))
# And these coud be Dependent Variable
#
#
# Marketing Data: Price/promotions,Direct Marketing,Sales force, Distribution,Product
#
# Media Data: Paid,Owner,Earned
#
# External Factors: Market Trends, Seasonality, Competitiveness
