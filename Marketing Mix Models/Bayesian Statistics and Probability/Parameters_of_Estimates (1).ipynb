# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***properties of estimators along with their mathematical formulas:***

# %% [markdown]
# **Consistency:**
#
# An estimator is consistent if it converges in probability to the true value of the parameter as the sample size increases.Mathematically, an estimator
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This means as the sample gets large, the estimator converges in probabiity to theta

# %% [markdown]
# **Unbiasedness:**
#
# An estimator is unbiased if its expected value is equal to the true value of the parameter being estimated.
# Mathematically, an estimator
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The Estimator is unbiased if it is centered on the true

# %% [markdown]
# **Efficiency:**
#
# ![image.png](data:image/png;base64,...)
