# %%
# import pandas
import pandas as pd
pd.options.display.float_format = '{:.0f}'.format
pd.set_option('display.width', 85)
pd.set_option('display.max_columns', 5)

# import the land temperature data
percapitaGDP = pd.read_excel("/content/GDPpercapita.xlsx",
   skiprows=4,
   skipfooter=1,
   usecols="A,C:T")

# %%
percapitaGDP
# Out:
#              Albania  Unnamed: 2  ...  Unnamed: 18  Unnamed: 19
# 0            Algeria        1085  ...         1748         1848
# 1     American Samoa         NaN  ...          NaN          NaN
# 2            Andorra         NaN  ...        18394        18039
# 3             Angola         NaN  ...          NaN          NaN
# 4           Anguilla         NaN  ...          NaN          NaN
# ..               ...         ...  ...          ...          ...
# 265      Wake Island         NaN  ...          NaN          NaN
# 266          Bonaire         NaN  ...          NaN          NaN
# 267             Sark         NaN  ...          NaN          NaN
# 268   Chinese Taipei         NaN  ...          NaN          NaN
# 269  Saint Eustatius         NaN  ...          NaN          NaN
#
# [270 rows x 19 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(percapitaGDP, *['Unnamed: 2'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(percapitaGDP, *['Unnamed: 3'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(percapitaGDP, *['Unnamed: 4'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(percapitaGDP, *['Unnamed: 5'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(percapitaGDP, *['Unnamed: 2'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(percapitaGDP, *['Unnamed: 3'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(percapitaGDP, *['Unnamed: 4'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(percapitaGDP, *['Unnamed: 5'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(percapitaGDP, *[[['Unnamed: 2', 'Unnamed: 3'], ['Unnamed: 3', 'Unnamed: 4'], ['Unnamed: 4', 'Unnamed: 5'], ['Unnamed: 5', 'Unnamed: 6']]], **{})
# chart

# %%
percapitaGDP.head()
# Out:
#           Albania  Unnamed: 2  ...  Unnamed: 18  Unnamed: 19
# 0         Algeria        1085  ...         1748         1848
# 1  American Samoa         NaN  ...          NaN          NaN
# 2         Andorra         NaN  ...        18394        18039
# 3          Angola         NaN  ...          NaN          NaN
# 4        Anguilla         NaN  ...          NaN          NaN
#
# [5 rows x 19 columns]

# %%
percapitaGDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Albania      270 non-null    object
#  1   Unnamed: 2   97 non-null     float64
#  2   Unnamed: 3   97 non-null     float64
#  3   Unnamed: 4   97 non-null     float64
#  4   Unnamed: 5   97 non-null     float64
#  5   Unnamed: 6   103 non-null    float64
#  6   Unnamed: 7   105 non-null    float64
#  7   Unnamed: 8   106 non-null    float64
#  8   Unnamed: 9   107 non-null    float64
#  9   Unnamed: 10  107 non-null    float64
#  10  Unnamed: 11  119 non-null    float64
#  11  Unnamed: 12  119 non-null    float64
#  12  Unnamed: 13  119 non-null    float64
#  13  Unnamed: 14  119 non-null    float64
#  14  Unnamed: 15  120 non-null    float64
#  15  Unnamed: 16  124 non-null    float64
#  16  Unnamed: 17  125 non-null    float64
#  17  Unnamed: 18  130 non-null    float64
#  18  Unnamed: 19  130 non-null    float64
# dtypes: float64(18), object(1)
# memory usage: 40.2+ KB

# %%
percapitaGDP.isnull().sum()
# Out:
# Albania          0
# Unnamed: 2     173
# Unnamed: 3     173
# Unnamed: 4     173
# Unnamed: 5     173
# Unnamed: 6     167
# Unnamed: 7     165
# Unnamed: 8     164
# Unnamed: 9     163
# Unnamed: 10    163
# Unnamed: 11    151
# Unnamed: 12    151
# Unnamed: 13    151
# Unnamed: 14    151
# Unnamed: 15    150
# Unnamed: 16    146
# Unnamed: 17    145
# Unnamed: 18    140
# Unnamed: 19    140
# dtype: int64

# %%
# import pandas
import pandas as pd
pd.options.display.float_format = '{:.0f}'.format
pd.set_option('display.width', 85)
pd.set_option('display.max_columns', 5)

# import the land temperature data
percapitaGDP = pd.read_excel("/content/GDPpercapita.xlsx",
   sheet_name="Data",
   skiprows=4,
   skipfooter=1,
   usecols="A,C:T")

percapitaGDP.head()
percapitaGDP.info()

# rename the Year column to metro
percapitaGDP.rename(columns={'Albania':'metro'}, inplace=True)
percapitaGDP.metro.str.startswith(' ').any()
percapitaGDP.metro.str.endswith(' ').any()
percapitaGDP.metro = percapitaGDP.metro.str.strip()

# convert the data columns to numeric
for col in percapitaGDP.columns[1:]:
  percapitaGDP[col] = pd.to_numeric(percapitaGDP[col], errors='coerce')
  percapitaGDP.rename(columns={col:'pcGDP'+col}, inplace=True)

percapitaGDP.head()
percapitaGDP.dtypes
percapitaGDP.describe()

# remove rows where all of the per capita GDP values are missing
percapitaGDP.dropna(subset=percapitaGDP.columns[1:], how="all", inplace=True)
percapitaGDP.describe()
percapitaGDP.head()
percapitaGDP.shape

# set an index using the metropolitan area column
percapitaGDP.metro.count()
percapitaGDP.metro.nunique()
percapitaGDP.set_index('metro', inplace=True)
percapitaGDP.head()
#percapitaGDP.loc['AUS02: Greater Melbourne']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Albania      270 non-null    object
#  1   Unnamed: 2   97 non-null     float64
#  2   Unnamed: 3   97 non-null     float64
#  3   Unnamed: 4   97 non-null     float64
#  4   Unnamed: 5   97 non-null     float64
#  5   Unnamed: 6   103 non-null    float64
#  6   Unnamed: 7   105 non-null    float64
#  7   Unnamed: 8   106 non-null    float64
#  8   Unnamed: 9   107 non-null    float64
#  9   Unnamed: 10  107 non-null    float64
#  10  Unnamed: 11  119 non-null    float64
#  11  Unnamed: 12  119 non-null    float64
#  12  Unnamed: 13  119 non-null    float64
#  13  Unnamed: 14  119 non-null    float64
#  14  Unnamed: 15  120 non-null    float64
#  15  Unnamed: 16  124 non-null    float64
#  16  Unnamed: 17  125 non-null    float64
#  17  Unnamed: 18  130 non-null    float64
#  18  Unnamed: 19  130 non-null    float64
# dtypes: float64(18), object(1)
# memory usage: 40.2+ KB
#                      pcGDPUnnamed: 2  pcGDPUnnamed: 3  ...  pcGDPUnnamed: 18  \
# metro                                                  ...
# Algeria                         1085              856  ...              1748
# Andorra                          NaN              NaN  ...             18394
# Antigua and Barbuda              NaN              NaN  ...              3816
# Argentina                       5448             5317  ...              7194
# Australia                       9452             9351  ...             13918
#
#                      pcGDPUnnamed: 19
# metro
# Algeria                          1848
# Andorra                         18039
# Antigua and Barbuda              3963
# Argentina                        6768
# Australia                       13879
#
# [5 rows x 18 columns]

# %%
# remove rows where all of the per capita GDP values are missing
percapitaGDP.dropna(subset=percapitaGDP.columns[1:],inplace=True)
percapitaGDP.describe()
percapitaGDP.head()
percapitaGDP.shape
# Out:
# (97, 18)
