# %% [markdown]
# # Splitting of Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# <h2> Importing Libraries </h2>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h2> Importing Dataset </h2>

# %%
df = pd.read_excel("/content/Salary_Dataset_02.xls")

# %%
df.head()
# Out:
#    Australia  Canada  Dubai  USA  Salary  YearsExperience  Purchased
# 0          0       0      1    0   39343              1.1          0
# 1          0       1      0    0   46205              1.3          1
# 2          0       1      0    0   37731              1.5          0
# 3          0       1      0    0   43525              2.0          0
# 4          0       0      0    1   39891              2.2          0

# %%
# In the code above, train_test_split is used to split your data into training and testing sets.
# You can specify the test_size parameter to control the proportion of data to allocate for testing (in this case, 20% is used for testing).
# The random_state parameter is set for reproducibility.

# Make sure to replace your_predictor_data and your_target_data with your actual data.
# X_train, X_test, y_train, and y_test will contain the respective portions of your data,
# where X_train is your training predictor data, y_train is your training target data,
# X_test is your testing predictor data, and y_test is your testing target data.

# %% [markdown]
# <h2> Dividing into Target and Predictor Variables </h2>

# %%
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#     Australia  Canada  Dubai  USA  Salary  YearsExperience  Purchased
# 0           0       0      1    0   39343              1.1          0
# 1           0       1      0    0   46205              1.3          1
# 2           0       1      0    0   37731              1.5          0
# 3           0       1      0    0   43525              2.0          0
# 4           0       0      0    1   39891              2.2          0
# 5           0       0      1    0   56642              2.9          0
# 6           0       1      0    0   60150              3.0          1
# 7           1       0      0    0   54445              3.2          0
# 8           0       0      1    0   64445              3.2          1
# 9           0       0      1    0   57189              3.7          0
# 10          0       0      1    0   63218              3.9          1
# 11          0       0      0    1   55794              4.0          0
# ...

# %%
features = df.drop('Purchased', axis=1)  # Features (predictor variables)
labels = df['Purchased']  # Target variable
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# %%
features
# Out:
#     Australia  Canada  Dubai  USA  Salary  YearsExperience
# 0           0       0      1    0   39343              1.1
# 1           0       1      0    0   46205              1.3
# 2           0       1      0    0   37731              1.5
# 3           0       1      0    0   43525              2.0
# 4           0       0      0    1   39891              2.2
# 5           0       0      1    0   56642              2.9
# 6           0       1      0    0   60150              3.0
# 7           1       0      0    0   54445              3.2
# 8           0       0      1    0   64445              3.2
# 9           0       0      1    0   57189              3.7
# 10          0       0      1    0   63218              3.9
# 11          0       0      0    1   55794              4.0
# 12          0       0      1    0   56957              4.0
# 13          0       1      0    0   57081              4.1
# 14          1       0      0    0   61111              4.5
# ...

# %%
labels
# Out:
# 0     0
# 1     1
# 2     0
# 3     0
# 4     0
# 5     0
# 6     1
# 7     0
# 8     1
# 9     0
# 10    1
# 11    0
# 12    1
# 13    0
# 14    0
# 15    0
# 16    0
# 17    0
# 18    1
# 19    0
# 20    0
# 21    0
# 22    0
# 23    1
# 24    0
# 25    1
# 26    0
# 27    1
# 28    0
# 29    1
# Name: Purchased, dtype: int64

# %%
X_train
# Out:
#     Australia  Canada  Dubai  USA  Salary  YearsExperience
# 28          0       0      0    1  122391             10.3
# 24          0       0      1    0  109431              8.7
# 12          0       0      1    0   56957              4.0
# 0           0       0      1    0   39343              1.1
# 4           0       0      0    1   39891              2.2
# 16          0       0      0    1   66029              5.1
# 5           0       0      1    0   56642              2.9
# 13          0       1      0    0   57081              4.1
# 11          0       0      0    1   55794              4.0
# 22          1       0      0    0  101302              7.9
# 1           0       1      0    0   46205              1.3
# 2           0       1      0    0   37731              1.5
# 25          1       0      0    0  105582              9.0
# 3           0       1      0    0   43525              2.0
# 21          1       0      0    0   98273              7.1
# ...

# %%
X_test
# Out:
#     Australia  Canada  Dubai  USA  Salary  YearsExperience
# 27          0       0      0    1  112635              9.6
# 15          0       0      0    1   67938              4.9
# 23          1       0      0    0  113812              8.2
# 17          0       1      0    0   83088              5.3
# 8           0       0      1    0   64445              3.2
# 9           0       0      1    0   57189              3.7

# %%
#Here we can see X is predictor variables even though it is divided into train and test x means it is among predictor data only
# using X_train we are training the model telling that here are the inputs given to you
# y train means telling model that these are the outputs you got for the x train inputs
# X_test means we are checking and testing the model by given pother inputs
# Y_test this means testing model whether is is predicting correct output only the given test inputs.

# %%
y_train
# Out:
# 28    0
# 24    0
# 12    1
# 0     0
# 4     0
# 16    0
# 5     0
# 13    0
# 11    0
# 22    0
# 1     1
# 2     0
# 25    1
# 3     0
# 21    0
# 26    0
# 18    1
# 29    1
# 20    0
# 7     0
# 10    1
# 14    0
# 19    0
# 6     1
# Name: Purchased, dtype: int64

# %%
y_test
# Out:
# 27    1
# 15    0
# 23    1
# 17    0
# 8     1
# 9     0
# Name: Purchased, dtype: int64

# %% [markdown]
# <h2> Divide Data as Training Set and Testing Set </h2>
